# %%
# Import relevant libraries

# %%
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go
import cufflinks as cf
#Allows the ability to produce plots in Jupyter Notebook
from plotly.offline import init_notebook_mode,iplot,plot
import requests
import json
import prettytable

# %%
#Confirms the connection between plotly and Jupyter Notebook
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Import quandl library
# Enter authentication key
# enter date of creation of api version library

# %%
import quandl
quandl.ApiConfig.api_key = 'Mm_qHSXMsN3XriByiv9P'
quandl.ApiConfig.api_version = '2015-04-09'

# %%
# create a data frame with the Consumer Price Index information collected from the YALE/CPIQ table, using my authntication token
# create a data frame with the Consumer Price Index information collected from the YALE/CPIQ table, using my authntication token from 
# https://www.quandl.com/data/YALE/CPIQ-Historical-Housing-Market-Data-Consumer-Price-Index-Quarterly

# %%
#Fetching the data that is equivelant to the ZILL codes by using my api_key token
Louisiana = quandl.get("ZILL/S00025_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Rhode_Island = quandl.get("ZILL/S00041_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Alaska = quandl.get("ZILL/S00045_A", authtoken="Mm_qHSXMsN3XriByiv9P")

# %%
Ohio = quandl.get("ZILL/S00007_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Vermont = quandl.get("ZILL/S00047_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Indiana = quandl.get("ZILL/S00015_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Georgia = quandl.get("ZILL/S00009_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Tennessee = quandl.get("ZILL/S00017_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Wisconsin = quandl.get("ZILL/S00020_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Massachusetts = quandl.get("ZILL/S00014_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Kentucky = quandl.get("ZILL/S00026_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Connecticut = quandl.get("ZILL/S00029_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Oregon = quandl.get("ZILL/S00027_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Mississippi = quandl.get("ZILL/S00031_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Montana = quandl.get("ZILL/S00042_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Maine = quandl.get("ZILL/S00051_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Iowa = quandl.get("ZILL/S00030_A", authtoken="Mm_qHSXMsN3XriByiv9P")

# %%
New_Jersey = quandl.get("ZILL/S00011_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Illinois = quandl.get("ZILL/S00005_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Missouri = quandl.get("ZILL/S00018_A", authtoken="Mm_qHSXMsN3XriByiv9P")
New_York = quandl.get("ZILL/S00003_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Arizona = quandl.get("ZILL/S00016_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Pennsylvania = quandl.get("ZILL/S00006_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Virginia = quandl.get("ZILL/S00012_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Texas = quandl.get("ZILL/S00002_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Florida = quandl.get("ZILL/S00004_A", authtoken="Mm_qHSXMsN3XriByiv9P")
North_Carolina = quandl.get("ZILL/S00010_A", authtoken="Mm_qHSXMsN3XriByiv9P")
California = quandl.get("ZILL/S00001_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Michigan = quandl.get("ZILL/S00008_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Maryland = quandl.get("ZILL/S00019_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Washington = quandl.get("ZILL/S00013_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Minnesota = quandl.get("ZILL/S00021_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Alabama = quandl.get("ZILL/S00023_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Oklahoma = quandl.get("ZILL/S00028_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Arkansas = quandl.get("ZILL/S00032_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Utah = quandl.get("ZILL/S00033_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Nevada = quandl.get("ZILL/S00034_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Nebraska = quandl.get("ZILL/S00037_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Idaho = quandl.get("ZILL/S00038_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Kansas = quandl.get("ZILL/S00049_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Wyoming = quandl.get("ZILL/S00050_A", authtoken="Mm_qHSXMsN3XriByiv9P")
West_Virginia = quandl.get("ZILL/S00036_A", authtoken="Mm_qHSXMsN3XriByiv9P")
New_Mexico = quandl.get("ZILL/S00035_A", authtoken="Mm_qHSXMsN3XriByiv9P")
New_Hampshire = quandl.get("ZILL/S00040_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Delaware = quandl.get("ZILL/S00043_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Hawaii = quandl.get("ZILL/S00039_A", authtoken="Mm_qHSXMsN3XriByiv9P")
North_Dakota = quandl.get("ZILL/S00046_A", authtoken="Mm_qHSXMsN3XriByiv9P")
District_of_Columbia = quandl.get("ZILL/S00048_A", authtoken="Mm_qHSXMsN3XriByiv9P")
Colorado = quandl.get("ZILL/S00022_A", authtoken="Mm_qHSXMsN3XriByiv9P")
South_Dakota = quandl.get("ZILL/S00044_A", authtoken="Mm_qHSXMsN3XriByiv9P")
South_Carolina = quandl.get("ZILL/S00024_A", authtoken="Mm_qHSXMsN3XriByiv9P")

# %%
#Checking the first 5 rows of each data frame created above
Arizona.head()
# Out:
#                Value
# Date
# 1996-04-30  102900.0
# 1996-05-31  103300.0
# 1996-06-30  103600.0
# 1996-07-31  103800.0
# 1996-08-31  103900.0

# %%
#Resetting the index of each data frame 
AL = Alabama.reset_index(drop=False)
AK = Alaska.reset_index(drop=False)
AZ = Arizona.reset_index(drop=False)
AR = Arkansas.reset_index(drop=False)
CA = California.reset_index(drop=False)
CO = Colorado.reset_index(drop=False)
CT = Connecticut.reset_index(drop=False)
DC = District_of_Columbia.reset_index(drop=False)
DE = Delaware.reset_index(drop=False)
FL = Florida.reset_index(drop=False)
GA = Georgia.reset_index(drop=False)
HI = Hawaii.reset_index(drop=False)
ID = Idaho.reset_index(drop=False)
IL = Illinois.reset_index(drop=False)
IN = Indiana.reset_index(drop=False)
IA = Iowa.reset_index(drop=False)
KS = Kansas.reset_index(drop=False)
KY = Kentucky.reset_index(drop=False)
LA = Louisiana.reset_index(drop=False)
ME = Maine.reset_index(drop=False)
MD = Maryland.reset_index(drop=False)
MA = Massachusetts.reset_index(drop=False)
MI = Michigan.reset_index(drop=False)
MN = Minnesota.reset_index(drop=False)
MS = Mississippi.reset_index(drop=False)
MO = Missouri.reset_index(drop=False)
MT = Montana.reset_index(drop=False)
NE = Nebraska.reset_index(drop=False)
NV = Nevada.reset_index(drop=False)
NH = New_Hampshire.reset_index(drop=False)
NJ = New_Jersey.reset_index(drop=False)
NM = New_Mexico.reset_index(drop=False)
NY = New_York.reset_index(drop=False)
NC = North_Carolina.reset_index(drop=False)
ND = North_Dakota.reset_index(drop=False)
OH = Ohio.reset_index(drop=False)
OK = Oklahoma.reset_index(drop=False)
OR = Oregon.reset_index(drop=False)
PA = Pennsylvania.reset_index(drop=False)
RI = Rhode_Island.reset_index(drop=False)
SC = South_Carolina.reset_index(drop=False)
SD = South_Dakota.reset_index(drop=False)
TN = Tennessee.reset_index(drop=False)
TX = Texas.reset_index(drop=False)
UT = Utah.reset_index(drop=False)
VT = Vermont.reset_index(drop=False)
VA = Virginia.reset_index(drop=False)
WA = Washington.reset_index(drop=False)
WV = West_Virginia.reset_index(drop=False)
WI = Wisconsin.reset_index(drop=False)
WY = Wyoming.reset_index(drop=False)
#newdf = Arizona[(Arizona['Date']>1999-12-31)]
#keep = [1999-12-31]
#keep = Arizona[Arizona['Date'].isin(keep)]

# %%
#Viewing the frist 5 rows of AL
AL.head()
# Out:
#         Date    Value
# 0 1996-04-30  83500.0
# 1 1996-05-31  83400.0
# 2 1996-06-30  83700.0
# 3 1996-07-31  83800.0
# 4 1996-08-31  83700.0

# %%
#Filtering through each data frame and only selecting the rows in which the date is no earlier that 31st Deember 2009
AL = AL[(AL['Date']>'2005-12-31')]
AK = AK[(AK['Date']>'2005-12-31')]
AZ = AZ[(AZ['Date']>'2005-12-31')]
AR = AR[(AR['Date']>'2005-12-31')]
CA = CA[(CA['Date']>'2005-12-31')]
CO = CO[(CO['Date']>'2005-12-31')]
CT = CT[(CT['Date']>'2005-12-31')]
DC = DC[(DC['Date']>'2005-12-31')]
DE = DE[(DE['Date']>'2005-12-31')]
FL = FL[(FL['Date']>'2005-12-31')]
GA = GA[(GA['Date']>'2005-12-31')]
HI = HI[(HI['Date']>'2005-12-31')]
ID = ID[(ID['Date']>'2005-12-31')]
IL = IL[(IL['Date']>'2005-12-31')]
IN = IN[(IN['Date']>'2005-12-31')]
IA = IA[(IA['Date']>'2005-12-31')]
KS = KS[(KS['Date']>'2005-12-31')]
KY = KY[(KY['Date']>'2005-12-31')]
LA = LA[(LA['Date']>'2005-12-31')]
ME = ME[(ME['Date']>'2005-12-31')]
MD = MD[(MD['Date']>'2005-12-31')]
MA = MA[(MA['Date']>'2005-12-31')]
MI = MI[(MI['Date']>'2005-12-31')]
MN = MN[(MN['Date']>'2005-12-31')]
MS = MS[(MS['Date']>'2005-12-31')]
MO = MO[(MO['Date']>'2005-12-31')]
MT = MT[(MT['Date']>'2005-12-31')]
NE = NE[(NE['Date']>'2005-12-31')]
NV = NV[(NV['Date']>'2005-12-31')]
NH = NH[(NH['Date']>'2005-12-31')]
NJ = NJ[(NJ['Date']>'2005-12-31')]
NM = NM[(NM['Date']>'2005-12-31')]
NY = NY[(NY['Date']>'2005-12-31')]
NC = NC[(NC['Date']>'2005-12-31')]
ND = ND[(ND['Date']>'2005-12-31')]
OH = OH[(OH['Date']>'2005-12-31')]
OK = OK[(OK['Date']>'2005-12-31')]
OR = OR[(OR['Date']>'2005-12-31')]
PA = PA[(PA['Date']>'2005-12-31')]
RI = RI[(RI['Date']>'2005-12-31')]
SC = SC[(SC['Date']>'2005-12-31')]
SD = SD[(SD['Date']>'2005-12-31')]
TN = TN[(TN['Date']>'2005-12-31')]
TX = TX[(TX['Date']>'2005-12-31')]
UT = UT[(UT['Date']>'2005-12-31')]
VT = VT[(VT['Date']>'2005-12-31')]
VA = VA[(VA['Date']>'2005-12-31')]
WA = WA[(WA['Date']>'2005-12-31')]
WV = WV[(WV['Date']>'2005-12-31')]
WI = WI[(WI['Date']>'2005-12-31')]
WY = WY[(WY['Date']>'2005-12-31')]

# %%
#Viewing some of the data frames
AL,AK,AZ,AR,CA,CO,CT,DE,DC,FL,GA,HI,ID,IL,IN,IA,KS,KY,LA,ME,MD,MA,MI
# Out:
# (          Date     Value
#  117 2006-01-31  124000.0
#  118 2006-02-28  124700.0
#  119 2006-03-31  125200.0
#  120 2006-04-30  125600.0
#  121 2006-05-31  126100.0
#  122 2006-06-30  126600.0
#  123 2006-07-31  127200.0
#  124 2006-08-31  127600.0
#  125 2006-09-30  127700.0
#  126 2006-10-31  127800.0
#  127 2006-11-30  128300.0
#  128 2006-12-31  129100.0
#  129 2007-01-31  129400.0
#  130 2007-02-28  129300.0
#  131 2007-03-31  129300.0
#  132 2007-04-30  129300.0
#  133 2007-05-31  129200.0
#  134 2007-06-30  129300.0
#  135 2007-07-31  129700.0
#  136 2007-08-31  129900.0
#  137 2007-09-30  130000.0
#  138 2007-10-31  130000.0
#  139 2007-11-30  129500.0
#  140 2007-12-31  128400.0
#  141 2008-01-31  127400.0
#  142 2008-02-29  126800.0
#  143 2008-03-31  126500.0
#  144 2008-04-30  126500.0
#  145 2008-05-31  126700.0
#  146 2008-06-30  127300.0
#  ..         ...       ...
#  220 2014-08-31  121100.0
#  221 2014-09-30  121400.0
#  222 2014-10-31  121800.0
# ...

# %%
#Assigning the data of AL to a new data frame called house_prices
house_prices= AL

# %%
#Viewing the house_prices data frame
house_prices
# Out:
#           Date     Value
# 117 2006-01-31  124000.0
# 118 2006-02-28  124700.0
# 119 2006-03-31  125200.0
# 120 2006-04-30  125600.0
# 121 2006-05-31  126100.0
# 122 2006-06-30  126600.0
# 123 2006-07-31  127200.0
# 124 2006-08-31  127600.0
# 125 2006-09-30  127700.0
# 126 2006-10-31  127800.0
# 127 2006-11-30  128300.0
# 128 2006-12-31  129100.0
# 129 2007-01-31  129400.0
# 130 2007-02-28  129300.0
# 131 2007-03-31  129300.0
# 132 2007-04-30  129300.0
# 133 2007-05-31  129200.0
# 134 2007-06-30  129300.0
# 135 2007-07-31  129700.0
# 136 2007-08-31  129900.0
# 137 2007-09-30  130000.0
# 138 2007-10-31  130000.0
# 139 2007-11-30  129500.0
# 140 2007-12-31  128400.0
# 141 2008-01-31  127400.0
# 142 2008-02-29  126800.0
# 143 2008-03-31  126500.0
# 144 2008-04-30  126500.0
# 145 2008-05-31  126700.0
# 146 2008-06-30  127300.0
# ..         ...       ...
# 220 2014-08-31  121100.0
# 221 2014-09-30  121400.0
# 222 2014-10-31  121800.0
# 223 2014-11-30  122000.0
# 224 2014-12-31  121800.0
# ...

# %%
# In the following 106 rows I will be Joining tha Value column of each state data frame to the house_prices data frame, such as
# house_prices = house_prices.merge(AK,how='left', left_on='Date', right_on='Date')
# matching by Date.  When a column is added to the house_prices data frame it carries over the same name of the column
# which in every case is Value, therefore I will also need to rename each coulm as it is joined to the house_prices
# data frame using the following command - 
# house_prices.rename(columns={'Value_x':'Name of data frame','Value_y':'name of data frame'}, inplace=True)

# %%
house_prices = house_prices.merge(AK,how='left', left_on='Date', right_on='Date')

# %%
house_prices
# Out:
#           Date   Value_x   Value_y
# 0   2006-01-31  124000.0  235100.0
# 1   2006-02-28  124700.0  237100.0
# 2   2006-03-31  125200.0  238700.0
# 3   2006-04-30  125600.0  239000.0
# 4   2006-05-31  126100.0  238500.0
# 5   2006-06-30  126600.0  237700.0
# 6   2006-07-31  127200.0  236100.0
# 7   2006-08-31  127600.0  234700.0
# 8   2006-09-30  127700.0  235300.0
# 9   2006-10-31  127800.0  237200.0
# 10  2006-11-30  128300.0  239000.0
# 11  2006-12-31  129100.0  243500.0
# 12  2007-01-31  129400.0  249500.0
# 13  2007-02-28  129300.0  255300.0
# 14  2007-03-31  129300.0  258800.0
# 15  2007-04-30  129300.0  261500.0
# 16  2007-05-31  129200.0  261900.0
# 17  2007-06-30  129300.0  262700.0
# 18  2007-07-31  129700.0  264000.0
# 19  2007-08-31  129900.0  265600.0
# 20  2007-09-30  130000.0  265700.0
# 21  2007-10-31  130000.0  265500.0
# 22  2007-11-30  129500.0  264700.0
# 23  2007-12-31  128400.0  265900.0
# 24  2008-01-31  127400.0  267800.0
# 25  2008-02-29  126800.0  268200.0
# ...

# %%
#Renaming the column headings
house_prices.rename(columns={'Value_x':'AL','Value_y':'AK'}, inplace=True)

# %%
house_prices.head()
# Out:
#         Date        AL        AK
# 0 2006-01-31  124000.0  235100.0
# 1 2006-02-28  124700.0  237100.0
# 2 2006-03-31  125200.0  238700.0
# 3 2006-04-30  125600.0  239000.0
# 4 2006-05-31  126100.0  238500.0

# %%
#Joining tha Value column of AZ to the house_prices data frame, matching by Date
house_prices = house_prices.merge(AZ,how='left', left_on='Date', right_on='Date')

# %%
house_prices.head()
# Out:
#         Date        AL        AK     Value
# 0 2006-01-31  124000.0  235100.0  259900.0
# 1 2006-02-28  124700.0  237100.0  261600.0
# 2 2006-03-31  125200.0  238700.0  262900.0
# 3 2006-04-30  125600.0  239000.0  263500.0
# 4 2006-05-31  126100.0  238500.0  263500.0

# %%
house_prices.rename(columns={'Value':'AZ'}, inplace=True)

# %%
house_prices.head()
# Out:
#         Date        AL        AK        AZ
# 0 2006-01-31  124000.0  235100.0  259900.0
# 1 2006-02-28  124700.0  237100.0  261600.0
# 2 2006-03-31  125200.0  238700.0  262900.0
# 3 2006-04-30  125600.0  239000.0  263500.0
# 4 2006-05-31  126100.0  238500.0  263500.0

# %%
house_prices = house_prices.merge(AR,how='left', left_on='Date', right_on='Date')

# %%
house_prices.head()
# Out:
#         Date        AL        AK        AZ    Value
# 0 2006-01-31  124000.0  235100.0  259900.0  93200.0
# 1 2006-02-28  124700.0  237100.0  261600.0  93600.0
# 2 2006-03-31  125200.0  238700.0  262900.0  94200.0
# 3 2006-04-30  125600.0  239000.0  263500.0  94500.0
# 4 2006-05-31  126100.0  238500.0  263500.0  94800.0

# %%
house_prices.rename(columns={'Value':'AR'}, inplace=True)

# %%
house_prices.head()
# Out:
#         Date        AL        AK        AZ       AR
# 0 2006-01-31  124000.0  235100.0  259900.0  93200.0
# 1 2006-02-28  124700.0  237100.0  261600.0  93600.0
# 2 2006-03-31  125200.0  238700.0  262900.0  94200.0
# 3 2006-04-30  125600.0  239000.0  263500.0  94500.0
# 4 2006-05-31  126100.0  238500.0  263500.0  94800.0

# %%
house_prices = house_prices.merge(CA,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'CA'}, inplace=True)

# %%
house_prices = house_prices.merge(CO,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'CO'}, inplace=True)

# %%
house_prices = house_prices.merge(CT,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'CT'}, inplace=True)

# %%
house_prices = house_prices.merge(DC,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'DC'}, inplace=True)

# %%
house_prices = house_prices.merge(DE,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'DE'}, inplace=True)

# %%
house_prices = house_prices.merge(FL,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'FL'}, inplace=True)

# %%
house_prices = house_prices.merge(GA,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'GA'}, inplace=True)

# %%
house_prices = house_prices.merge(HI,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'HI'}, inplace=True)

# %%
house_prices = house_prices.merge(ID,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'ID'}, inplace=True)

# %%
house_prices = house_prices.merge(IL,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'IL'}, inplace=True)

# %%
house_prices = house_prices.merge(IN,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'IN'}, inplace=True)

# %%
house_prices = house_prices.merge(IA,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'IA'}, inplace=True)

# %%
house_prices = house_prices.merge(KS,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'KS'}, inplace=True)

# %%
house_prices = house_prices.merge(KY,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'KY'}, inplace=True)

# %%
house_prices = house_prices.merge(LA,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'LA'}, inplace=True)

# %%
house_prices = house_prices.merge(ME,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'ME'}, inplace=True)

# %%
house_prices = house_prices.merge(MD,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'MD'}, inplace=True)

# %%
house_prices = house_prices.merge(MA,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'MA'}, inplace=True)

# %%
house_prices = house_prices.merge(MI,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'MI'}, inplace=True)

# %%
house_prices = house_prices.merge(MN,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'MN'}, inplace=True)

# %%
house_prices = house_prices.merge(MS,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'MS'}, inplace=True)

# %%
house_prices = house_prices.merge(MO,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'MO'}, inplace=True)

# %%
house_prices = house_prices.merge(MT,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'MT'}, inplace=True)

# %%
house_prices = house_prices.merge(NE,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'NE'}, inplace=True)

# %%
house_prices = house_prices.merge(NV,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'NV'}, inplace=True)

# %%
house_prices = house_prices.merge(NH,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'NH'}, inplace=True)

# %%
house_prices = house_prices.merge(NJ,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'NJ'}, inplace=True)

# %%
house_prices = house_prices.merge(NM,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'NM'}, inplace=True)

# %%
house_prices = house_prices.merge(NY,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'NY'}, inplace=True)

# %%
house_prices = house_prices.merge(NC,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'NC'}, inplace=True)

# %%
house_prices = house_prices.merge(ND,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'ND'}, inplace=True)

# %%
house_prices = house_prices.merge(OH,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'OH'}, inplace=True)

# %%
house_prices = house_prices.merge(OK,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'OK'}, inplace=True)

# %%
house_prices = house_prices.merge(OR,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'OR'}, inplace=True)

# %%
house_prices = house_prices.merge(PA,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'PA'}, inplace=True)

# %%
house_prices = house_prices.merge(RI,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'RI'}, inplace=True)

# %%
house_prices = house_prices.merge(SC,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'SC'}, inplace=True)

# %%
house_prices = house_prices.merge(SD,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'SD'}, inplace=True)

# %%
house_prices = house_prices.merge(TN,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'TN'}, inplace=True)

# %%
house_prices = house_prices.merge(TX,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'TX'}, inplace=True)

# %%
house_prices = house_prices.merge(UT,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'UT'}, inplace=True)

# %%
house_prices = house_prices.merge(VT,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'VT'}, inplace=True)

# %%
house_prices = house_prices.merge(VA,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'VA'}, inplace=True)

# %%
house_prices = house_prices.merge(WA,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'WA'}, inplace=True)

# %%
house_prices = house_prices.merge(WV,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'WV'}, inplace=True)

# %%
house_prices = house_prices.merge(WI,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'WI'}, inplace=True)

# %%
house_prices = house_prices.merge(WY,how='left', left_on='Date', right_on='Date')

# %%
house_prices.rename(columns={'Value':'WY'}, inplace=True)

# %%
#Renaming the column headings
#house_prices.rename(columns={'Value_x':'AL','Value_y':'AK'}, inplace=True)

# %%
# Viewing the complete house_prices data frame
house_prices
# Out:
#           Date        AL        AK        AZ        AR        CA        CO  \
# 0   2006-01-31  124000.0  235100.0  259900.0   93200.0  534500.0  222500.0
# 1   2006-02-28  124700.0  237100.0  261600.0   93600.0  536100.0  223300.0
# 2   2006-03-31  125200.0  238700.0  262900.0   94200.0  537500.0  223400.0
# 3   2006-04-30  125600.0  239000.0  263500.0   94500.0  538300.0  223600.0
# 4   2006-05-31  126100.0  238500.0  263500.0   94800.0  538300.0  223700.0
# 5   2006-06-30  126600.0  237700.0  263000.0   94800.0  537700.0  223500.0
# 6   2006-07-31  127200.0  236100.0  262100.0   95100.0  536600.0  223800.0
# 7   2006-08-31  127600.0  234700.0  260900.0   95700.0  534800.0  224400.0
# 8   2006-09-30  127700.0  235300.0  259400.0   95800.0  532400.0  224700.0
# 9   2006-10-31  127800.0  237200.0  257700.0   95300.0  529600.0  225300.0
# 10  2006-11-30  128300.0  239000.0  256100.0   95400.0  527000.0  226300.0
# ...

# %%
# Replacing any NAN values with 0
house_prices = house_prices.fillna(0)

# %%
# Viewing the changes
house_prices
# Out:
#           Date        AL        AK        AZ        AR        CA        CO  \
# 0   2006-01-31  124000.0  235100.0  259900.0   93200.0  534500.0  222500.0
# 1   2006-02-28  124700.0  237100.0  261600.0   93600.0  536100.0  223300.0
# 2   2006-03-31  125200.0  238700.0  262900.0   94200.0  537500.0  223400.0
# 3   2006-04-30  125600.0  239000.0  263500.0   94500.0  538300.0  223600.0
# 4   2006-05-31  126100.0  238500.0  263500.0   94800.0  538300.0  223700.0
# 5   2006-06-30  126600.0  237700.0  263000.0   94800.0  537700.0  223500.0
# 6   2006-07-31  127200.0  236100.0  262100.0   95100.0  536600.0  223800.0
# 7   2006-08-31  127600.0  234700.0  260900.0   95700.0  534800.0  224400.0
# 8   2006-09-30  127700.0  235300.0  259400.0   95800.0  532400.0  224700.0
# 9   2006-10-31  127800.0  237200.0  257700.0   95300.0  529600.0  225300.0
# 10  2006-11-30  128300.0  239000.0  256100.0   95400.0  527000.0  226300.0
# ...

# %%
# Setting the index as the Date column
house_prices.set_index("Date")
# Out:
#                   AL        AK        AZ        AR        CA        CO  \
# Date
# 2006-01-31  124000.0  235100.0  259900.0   93200.0  534500.0  222500.0
# 2006-02-28  124700.0  237100.0  261600.0   93600.0  536100.0  223300.0
# 2006-03-31  125200.0  238700.0  262900.0   94200.0  537500.0  223400.0
# 2006-04-30  125600.0  239000.0  263500.0   94500.0  538300.0  223600.0
# 2006-05-31  126100.0  238500.0  263500.0   94800.0  538300.0  223700.0
# 2006-06-30  126600.0  237700.0  263000.0   94800.0  537700.0  223500.0
# 2006-07-31  127200.0  236100.0  262100.0   95100.0  536600.0  223800.0
# 2006-08-31  127600.0  234700.0  260900.0   95700.0  534800.0  224400.0
# 2006-09-30  127700.0  235300.0  259400.0   95800.0  532400.0  224700.0
# 2006-10-31  127800.0  237200.0  257700.0   95300.0  529600.0  225300.0
# 2006-11-30  128300.0  239000.0  256100.0   95400.0  527000.0  226300.0
# 2006-12-31  129100.0  243500.0  254300.0   95900.0  523900.0  227100.0
# ...

# %%
#house_prices=house_prices.T

# %%
# Confirming the changes
house_prices
# Out:
#           Date        AL        AK        AZ        AR        CA        CO  \
# 0   2006-01-31  124000.0  235100.0  259900.0   93200.0  534500.0  222500.0
# 1   2006-02-28  124700.0  237100.0  261600.0   93600.0  536100.0  223300.0
# 2   2006-03-31  125200.0  238700.0  262900.0   94200.0  537500.0  223400.0
# 3   2006-04-30  125600.0  239000.0  263500.0   94500.0  538300.0  223600.0
# 4   2006-05-31  126100.0  238500.0  263500.0   94800.0  538300.0  223700.0
# 5   2006-06-30  126600.0  237700.0  263000.0   94800.0  537700.0  223500.0
# 6   2006-07-31  127200.0  236100.0  262100.0   95100.0  536600.0  223800.0
# 7   2006-08-31  127600.0  234700.0  260900.0   95700.0  534800.0  224400.0
# 8   2006-09-30  127700.0  235300.0  259400.0   95800.0  532400.0  224700.0
# 9   2006-10-31  127800.0  237200.0  257700.0   95300.0  529600.0  225300.0
# 10  2006-11-30  128300.0  239000.0  256100.0   95400.0  527000.0  226300.0
# ...

# %%
# Using the house_prices data frame, create a plot in jupyter notebook with iplot, setting Data as the x axis,
# and filling the areas with unique individual colours.  Then using vspan section off part off the graphpg to indicate the 
# recession period. x0 is the start and x1 is the en of the recession, using rgb to colour the area grey opacity 
# to control tha shade.  I then set the Titles for the x and y axis and the main grph title

# %%
house_prices.iplot(x='Date', fill=True, 
vspan={'x0':'2007-12-01','x1':'2009-06-30','color':'rgba(30,30,30,0.3)','fill':True,'opacity':.4},
xTitle='Date',yTitle='House Price ($)',title='House Prices')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Celticstu/258.embed" height="525px" width="100%"></iframe>
